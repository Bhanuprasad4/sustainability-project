# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhanuprasad4/sustainability-project/blob/main/solar%20panel%20damage%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<class_id> <x_center> <y_center> <width> <height>   # all normalized 0..1
# Out:
#   File "/tmp/ipython-input-1390726404.py", line 1
#     <class_id> <x_center> <y_center> <width> <height>   # all normalized 0..1
#     ^
# SyntaxError: invalid syntax

# %%
class_id = 0  # Example value
x_center = 0.5 # Example value (normalized)
y_center = 0.5 # Example value (normalized)
width = 0.1  # Example value (normalized)
height = 0.2 # Example value (normalized)

# You can then use these variables in your code
print(f"Class ID: {class_id}, Center: ({x_center}, {y_center}), Dimensions: ({width}, {height})")
# Out:
# Class ID: 0, Center: (0.5, 0.5), Dimensions: (0.1, 0.2)

# %%
/mnt/data/yolo_dataset/labels/train
/mnt/data/yolo_dataset/labels/val
/mnt/data/yolo_dataset/labels/test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-191453717.py in <cell line: 0>()
# ----> 1 mnt/data/yolo_dataset/labels/train()
#       2 mnt/data/yolo_dataset/labels/val()
#       3 mnt/data/yolo_dataset/labels/test()
#
# NameError: name 'mnt' is not defined

# %%
train_labels_path = "/mnt/data/yolo_dataset/labels/train"
val_labels_path = "/mnt/data/yolo_dataset/labels/val"
test_labels_path = "/mnt/data/yolo_dataset/labels/test"

# You can then use these variables to access the directories
print(f"Train labels path: {train_labels_path}")
print(f"Validation labels path: {val_labels_path}")
print(f"Test labels path: {test_labels_path}")
# Out:
# Train labels path: /mnt/data/yolo_dataset/labels/train
# Validation labels path: /mnt/data/yolo_dataset/labels/val
# Test labels path: /mnt/data/yolo_dataset/labels/test

# %%
# !pip install -r requirements.txt
# !python train_yolo.py --epochs 50 --imgsz 640 --batch 16 --model yolov8n.pt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# python3: can't open file '/content/train_yolo.py': [Errno 2] No such file or directory

# %%
# !python infer_yolo.py --weights runs/train/solar_yolo/weights/best.pt
# Out:
# python3: can't open file '/content/infer_yolo.py': [Errno 2] No such file or directory

# %%
# !python convert_voc_to_yolo.py --voc_dir /path/to/xml_and_images --out_labels /mnt/data/yolo_dataset/labels/train --classes crack hotspot soiling delamination junction_box ok
# Out:
# python3: can't open file '/content/convert_voc_to_yolo.py': [Errno 2] No such file or directory

# %%
# Edit classes.json to the classes you want
# !python quicklabel.py --images_dir /mnt/data/solar_dataset --classes classes.json --out_csv labels.csv
# Out:
# python3: can't open file '/content/quicklabel.py': [Errno 2] No such file or directory
